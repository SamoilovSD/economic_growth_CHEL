# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib
from scipy.optimize import curve_fit
from tqdm import tqdm
import csv

rc = {"font.family" : "serif", 
      "mathtext.fontset" : "stix"}
plt.rcParams.update(rc)
plt.rcParams["font.serif"] = ["Times New Roman"] + plt.rcParams["font.serif"]
matplotlib.rcParams.update({'font.size': 14})

# %%
mas_t = np.arange(1996,2021)
mas_t
# Out:
# array([1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        2018, 2019, 2020])

# %%
GDP_LTV = [2429, 2680, 2970, 3148, 3357, 3573, 4131, 5135, 6363, 7575, 9699, 14091, 16422, 12288, 11379, 13766, 13923, 15122, 15713, 13774, 14315, 15643, 17849, 17794, 17619]

# %%
GDP_LTH = [2327, 2830, 3166, 3113, 3293, 3525, 4141, 5499, 6700, 7854, 9230, 12285, 14944, 11820, 11987, 14376, 14376, 15729, 16551, 14258, 14998, 16843,19166,19555,19997]

# %%
GDP_EST = [3380, 3682, 4093, 4140, 4070, 4505, 5341, 7203, 8914, 10412, 12639, 16744, 18204, 14711, 14633, 17464, 17404, 19050, 20234, 17395, 18282, 20387, 23052, 23397, 23027]

# %%
GDP_RUS = [2643, 2737, 1834, 1330, 1771, 2100, 2377, 2975, 4102, 5323, 6920, 9101, 11635, 8562, 10674, 14311, 15420, 15974, 14095, 9313, 8704, 10720, 11287, 11497, 10126]

# %%
plt.figure(figsize=(10,6))
plt.plot(mas_t,GDP_EST,label='Эстония',color = 'b',linestyle = '-.')
plt.plot(mas_t,GDP_LTH,label='Литва',color = 'green',linestyle = ':')
plt.plot(mas_t,GDP_LTV,label='Латвия',color = 'black',linestyle = '--')
plt.plot(mas_t,GDP_RUS,label='Россия',color = 'r',linestyle = '-')
plt.ylabel('ВВП на душу населения, US $')
plt.xlabel('Год')
plt.legend()
plt.grid()
plt.savefig('GDP per capita',dpi=300)
